# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("austin_weather.csv")
data
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
#drop unnecessary column
data = data.drop(["Events", "Date", "SeaLevelPressureLowInches"], axis=1)
data
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
data = data.replace('T', 0)
data = data.replace('-',0)
data
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
data.to_csv("austin_weather_final.csv")

# %%
# again import library
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("austin_weather_final.csv")
data
# Out:
#       Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45             67            49
# 1              1         56        48        39             43            36
# 2              2         58        45        32             31            27
# 3              3         61        46        31             36            28
# 4              4         58        50        41             44            40
# ...          ...        ...       ...       ...            ...           ...
# 1314        1314        103        89        75             71            67
# 1315        1315        105        91        76             71            64
# 1316        1316        107        92        77             72            64
# 1317        1317        106        93        79             70            68
# 1318        1318         99        88        77             66            61
#
# ...

# %%
x = data.drop(['PrecipitationSumInches'], axis =1)

# %%
y = data['PrecipitationSumInches']

# %%
# reshaping it into 2d vector
y = y.to_numpy().reshape(-1, 1)

y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]], shape=(1319, 1))

# %%
day_index = 798
days = [ i for i in range(y.size)]

# %%
# intialise linear regression classifier

clf = LinearRegression()

# train the classifier
clf.fit(x,y)
# Out:
# LinearRegression()

# %%
# plot graph
print("The precipitation trend graph: ")
plt.scatter(days, y, color='g')
plt.scatter(days[day_index], y[day_index], color = 'r')
plt.title("Precipitation level")
plt.xlabel("Days")
plt.ylabel("Precipiation in inches")
plt.show()
x_vis = x.filter(["TempAvgF", "DewPointAvgF","HumidityAvgPercent", "SeaLevelPressureHighInches","VisibilityAvgMiles","WindAvgMPH"])
# Out:
# The precipitation trend graph:

# %%
plt.scatter(x_vis["TempAvgF"], y, color='b')
plt.xlabel("Average Temperature (F)")
plt.ylabel("Precipitation in inches")
plt.title("Temp vs Precipitation")
plt.show()

# %%
print("The precipitaion vs attributes trend graph: ")
for i in range(x_vis.columns.size):
    plt.subplot(3,2,i+1)
    plt.scatter(days, x_vis[x_vis.columns.values[i][:1000]], color='g')
    plt.scatter(days[day_index], x_vis[x_vis.columns.values[i]][day_index], color='r')
    plt.title(x_vis.columns.values[i])
# Out:
# The precipitaion vs attributes trend graph:

# %%
import seaborn as sns

sns.scatterplot(x=x_vis["TempAvgF"], y=x_vis["HumidityAvgPercent"], color='b')
# Out:
# <Axes: xlabel='TempAvgF', ylabel='HumidityAvgPercent'>

# %%
sns.scatterplot(
    x=x_vis["TempAvgF"],
    y=x_vis["WindAvgMPH"],
    hue=x_vis["HumidityAvgPercent"],   
    size=x_vis["VisibilityAvgMiles"],   
    palette="viridis",   
    sizes=(20, 200),                    
    alpha=0.7                           
)
plt.xlabel("Average Temperature (F)")
plt.ylabel("Average Wind Speed (MPH)")
plt.title("Temperature vs Wind Speed with Humidity & Visibility")
plt.legend(title="Humidity & Visibility")
plt.show()
